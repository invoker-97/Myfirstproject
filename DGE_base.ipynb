# %%
from platform import python_version
print(python_version())
# Out:
# 3.10.11

# %%
pip install pydeseq2
# Out:
# Requirement already satisfied: pydeseq2 in ./miniconda3/envs/py36/lib/python3.10/site-packages (0.3.5)
# Requirement already satisfied: anndata>=0.8.0 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from pydeseq2) (0.9.1)
# Requirement already satisfied: ipython in ./miniconda3/envs/py36/lib/python3.10/site-packages (from pydeseq2) (8.12.0)
# Requirement already satisfied: numpy>=1.23.0 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from pydeseq2) (1.25.0)
# Requirement already satisfied: pandas>=1.4.0 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from pydeseq2) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from pydeseq2) (1.3.0)
# Requirement already satisfied: scipy>=1.8.0 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from pydeseq2) (1.11.1)
# Requirement already satisfied: statsmodels in ./miniconda3/envs/py36/lib/python3.10/site-packages (from pydeseq2) (0.14.0)
# Requirement already satisfied: matplotlib>=3.6.2 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from pydeseq2) (3.7.1)
# Requirement already satisfied: h5py>=3 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from anndata>=0.8.0->pydeseq2) (3.9.0)
# Requirement already satisfied: natsort in ./miniconda3/envs/py36/lib/python3.10/site-packages (from anndata>=0.8.0->pydeseq2) (8.4.0)
# Requirement already satisfied: packaging>=20 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from anndata>=0.8.0->pydeseq2) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from pandas>=1.4.0->pydeseq2) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from pandas>=1.4.0->pydeseq2) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from scikit-learn>=1.1.0->pydeseq2) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from scikit-learn>=1.1.0->pydeseq2) (3.1.0)
# Requirement already satisfied: backcall in ./miniconda3/envs/py36/lib/python3.10/site-packages (from ipython->pydeseq2) (0.2.0)
# Requirement already satisfied: decorator in ./miniconda3/envs/py36/lib/python3.10/site-packages (from ipython->pydeseq2) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from ipython->pydeseq2) (0.18.1)
# Requirement already satisfied: matplotlib-inline in ./miniconda3/envs/py36/lib/python3.10/site-packages (from ipython->pydeseq2) (0.1.6)
# Requirement already satisfied: pickleshare in ./miniconda3/envs/py36/lib/python3.10/site-packages (from ipython->pydeseq2) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from ipython->pydeseq2) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from ipython->pydeseq2) (2.15.1)
# Requirement already satisfied: stack-data in ./miniconda3/envs/py36/lib/python3.10/site-packages (from ipython->pydeseq2) (0.2.0)
# Requirement already satisfied: traitlets>=5 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from ipython->pydeseq2) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from ipython->pydeseq2) (4.8.0)
# Requirement already satisfied: patsy>=0.5.2 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from statsmodels->pydeseq2) (0.5.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from jedi>=0.16->ipython->pydeseq2) (0.8.3)
# Requirement already satisfied: six in ./miniconda3/envs/py36/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels->pydeseq2) (1.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./miniconda3/envs/py36/lib/python3.10/site-packages (from pexpect>4.3->ipython->pydeseq2) (0.7.0)
# Requirement already satisfied: wcwidth in ./miniconda3/envs/py36/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->pydeseq2) (0.2.5)
# Requirement already satisfied: executing in ./miniconda3/envs/py36/lib/python3.10/site-packages (from stack-data->ipython->pydeseq2) (0.8.3)
# Requirement already satisfied: asttokens in ./miniconda3/envs/py36/lib/python3.10/site-packages (from stack-data->ipython->pydeseq2) (2.0.5)
# Requirement already satisfied: pure-eval in ./miniconda3/envs/py36/lib/python3.10/site-packages (from stack-data->ipython->pydeseq2) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show pydeseq2
# Out:
# Name: pydeseq2
# Version: 0.3.5
# Summary: A python implementation of DESeq2.
# Home-page:
# Author: Boris Muzellec, Maria Telenczuk, Vincent Cabelli and Mathieu Andreux
# Author-email: boris.muzellec@owkin.com
# License: MIT
# Location: /home/paras/miniconda3/envs/py36/lib/python3.10/site-packages
# Requires: anndata, ipython, matplotlib, numpy, pandas, scikit-learn, scipy, statsmodels
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats

import pandas as pd

# %%
counts = pd.read_csv('ASV-filtered-table.csv')
counts
# Out:
#                                                 geneid   S29   S30   S31
# 0                              g__Escherichia-Shigella  2978     0  5205
# 1            g__Asteroleplasma s__uncultured_bacterium  1867   768   110
# 2                                      g__Agathobacter    80  1215   104
# 3                                  g__Faecalibacterium     0  1099     0
# 4                                         g__Dialister     0  1054     0
# ..                                                 ...   ...   ...   ...
# 169          g__Family_XIII_AD3011_group s__metagenome    23     0     0
# 170          g__Elusimicrobium s__uncultured_bacterium     0     0    23
# 171   g__Christensenellaceae_R-7_group s__unculture...    22     0     0
# 172                           g__Moryella s__human_gut     0     0    22
# 173           g__Bacteroides s__Bacteroides_finegoldii    20     0     0
#
# [174 rows x 4 columns]

# %%
counts = counts.set_index('geneid')
counts
# Out:
#                                                      S29   S30   S31
# geneid
#  g__Escherichia-Shigella                            2978     0  5205
#  g__Asteroleplasma s__uncultured_bacterium          1867   768   110
#  g__Agathobacter                                      80  1215   104
#  g__Faecalibacterium                                   0  1099     0
#  g__Dialister                                          0  1054     0
# ...                                                  ...   ...   ...
#  g__Family_XIII_AD3011_group s__metagenome            23     0     0
#  g__Elusimicrobium s__uncultured_bacterium             0     0    23
#  g__Christensenellaceae_R-7_group s__uncultured...    22     0     0
#  g__Moryella s__human_gut                              0     0    22
#  g__Bacteroides s__Bacteroides_finegoldii             20     0     0
#
# [174 rows x 3 columns]

# %%
counts = counts[counts.sum(axis = 1) > 0]
counts
# Out:
#                                                      S29   S30   S31
# geneid
#  g__Escherichia-Shigella                            2978     0  5205
#  g__Asteroleplasma s__uncultured_bacterium          1867   768   110
#  g__Agathobacter                                      80  1215   104
#  g__Faecalibacterium                                   0  1099     0
#  g__Dialister                                          0  1054     0
# ...                                                  ...   ...   ...
#  g__Family_XIII_AD3011_group s__metagenome            23     0     0
#  g__Elusimicrobium s__uncultured_bacterium             0     0    23
#  g__Christensenellaceae_R-7_group s__uncultured...    22     0     0
#  g__Moryella s__human_gut                              0     0    22
#  g__Bacteroides s__Bacteroides_finegoldii             20     0     0
#
# [174 rows x 3 columns]

# %%
counts = counts.T
counts
# Out:
# geneid   g__Escherichia-Shigella   g__Asteroleplasma s__uncultured_bacterium  \
# S29                         2978                                        1867
# S30                            0                                         768
# S31                         5205                                         110
#
# geneid   g__Agathobacter   g__Faecalibacterium   g__Dialister  \
# S29                   80                     0              0
# S30                 1215                  1099           1054
# S31                  104                     0              0
#
# geneid   g__Christensenellaceae_R-7_group s__human_gut   g__Bacteroides  \
# S29                                                  0              567
# S30                                                  0               93
# S31                                                899              205
#
# geneid   g__Blautia  \
# S29               0
# S30             606
# S31               0
#
# geneid   g__Christensenellaceae_R-7_group s__uncultured_spirochete  \
# S29                                                    62
# S30                                                     0
# S31                                                   519
#
# geneid   g__Collinsella  ...   g__Incertae_Sedis   g__Lachnospiraceae_UCG-004  \
# S29                 157  ...                   0                            0
# S30                 346  ...                   0                            0
# S31                  66  ...                  31                           31
#
# geneid   g__Acinetobacter s__Acinetobacter_indicus   g__Parasutterella  \
# S29                                              0                  25
# S30                                              0                   0
# S31                                             29                   0
#
# geneid   g__Prevotella s__Prevotella_copri  \
# S29                                      0
# S30                                     25
# S31                                      0
#
# geneid   g__Family_XIII_AD3011_group s__metagenome  \
# S29                                             23
# S30                                              0
# S31                                              0
#
# geneid   g__Elusimicrobium s__uncultured_bacterium  \
# S29                                              0
# S30                                              0
# S31                                             23
#
# geneid   g__Christensenellaceae_R-7_group s__uncultured_Clostridia  \
# S29                                                    22
# S30                                                     0
# S31                                                     0
#
# geneid   g__Moryella s__human_gut   g__Bacteroides s__Bacteroides_finegoldii
# S29                             0                                         20
# S30                             0                                          0
# S31                            22                                          0
#
# [3 rows x 174 columns]

# %%
metadata = pd.read_table('metadata.txt')
metadata
# Out:
#   sample condition body-suit
# 0    S29   treated      PD-L
# 1    S30   control        CT
# 2    S31   treated      PD-H

# %%
metadata = metadata.set_index('sample')
metadata
# Out:
#        condition body-suit
# sample
# S29      treated      PD-L
# S30      control        CT
# S31      treated      PD-H

# %%
dds = DeseqDataSet(counts=counts,
            clinical=metadata,
            design_factors="condition")


#design_factors=["batch", "condition"] = ~ batch + condtion

# %%
dds.deseq2()
# Out:
# Fitting size factors...
# ... done in 0.00 seconds.
#
# Fitting dispersions...
# ... done in 0.09 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.08 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.09 seconds.
#
# Fitting LFCs...
# ... done in 0.11 seconds.
#
# Refitting 0 outliers.

# %%
dds
# Out:
# AnnData object with n_obs × n_vars = 3 × 174
#     obs: 'condition', 'body-suit'
#     uns: 'trend_coeffs', '_squared_logres', 'prior_disp_var'
#     obsm: 'design_matrix', 'size_factors'
#     varm: 'non_zero', '_rough_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced'
#     layers: 'normed_counts', '_mu_hat', '_mu_LFC', '_hat_diagonals', 'cooks'

# %%
stat_res = DeseqStats(dds, n_cpus=8, contrast = ('condition','treated','control'))

# %%
stat_res.summary()
# Out:
# Running Wald tests...
# ... done in 1.14 seconds.
#
# Log2 fold change & Wald test p-value: condition treated vs control
#                                                        baseMean  \
# geneid
#  g__Escherichia-Shigella                            3432.240340
#  g__Asteroleplasma s__uncultured_bacterium           862.349065
#  g__Agathobacter                                     359.205214
#  g__Faecalibacterium                                 256.605294
#  g__Dialister                                        246.098253
# ...                                                         ...
#  g__Family_XIII_AD3011_group s__metagenome             7.783177
#  g__Elusimicrobium s__uncultured_bacterium            10.713396
#  g__Christensenellaceae_R-7_group s__uncultured...     7.444778
#  g__Moryella s__human_gut                             10.247596
#  g__Bacteroides s__Bacteroides_finegoldii              6.767980
#
#                                                     log2FoldChange     lfcSE  \
# geneid
#  g__Escherichia-Shigella                                 15.285983  5.705350
#  g__Asteroleplasma s__uncultured_bacterium                0.929493  4.322670
#  g__Agathobacter                                         -2.909516  4.241998
#  g__Faecalibacterium                                    -11.778568  5.684878
#  g__Dialister                                           -11.718253  5.686845
# ...                                                            ...       ...
#  g__Family_XIII_AD3011_group s__metagenome                6.503808  6.529910
#  g__Elusimicrobium s__uncultured_bacterium                6.960748  6.527676
#  g__Christensenellaceae_R-7_group s__uncultured...        6.439782  6.530284
#  g__Moryella s__human_gut                                 6.896542  6.527949
#  g__Bacteroides s__Bacteroides_finegoldii                 6.302522  6.531142
#
#                                                         stat    pvalue  \
# geneid
#  g__Escherichia-Shigella                            2.679237  0.007379
#  g__Asteroleplasma s__uncultured_bacterium          0.215028  0.829746
#  g__Agathobacter                                   -0.685883  0.492787
#  g__Faecalibacterium                               -2.071912  0.038274
#  g__Dialister                                      -2.060589  0.039342
# ...                                                      ...       ...
#  g__Family_XIII_AD3011_group s__metagenome          0.996003  0.319249
#  g__Elusimicrobium s__uncultured_bacterium          1.066344  0.286268
#  g__Christensenellaceae_R-7_group s__uncultured...  0.986141  0.324064
#  g__Moryella s__human_gut                           1.056464  0.290756
#  g__Bacteroides s__Bacteroides_finegoldii           0.964995  0.334547
#
#                                                         padj
# geneid
#  g__Escherichia-Shigella                            0.306957
#  g__Asteroleplasma s__uncultured_bacterium          0.860265
#  g__Agathobacter                                    0.529289
#  g__Faecalibacterium                                0.306957
#  g__Dialister                                       0.306957
# ...                                                      ...
#  g__Family_XIII_AD3011_group s__metagenome          0.349367
#  g__Elusimicrobium s__uncultured_bacterium          0.321359
#  g__Christensenellaceae_R-7_group s__uncultured...  0.352419
#  g__Moryella s__human_gut                           0.324305
#  g__Bacteroides s__Bacteroides_finegoldii           0.361560
#
# [174 rows x 6 columns]

# %%
res = stat_res.results_df
res
# Out:
#                                                        baseMean  \
# geneid
#  g__Escherichia-Shigella                            3432.240340
#  g__Asteroleplasma s__uncultured_bacterium           862.349065
#  g__Agathobacter                                     359.205214
#  g__Faecalibacterium                                 256.605294
#  g__Dialister                                        246.098253
# ...                                                         ...
#  g__Family_XIII_AD3011_group s__metagenome             7.783177
#  g__Elusimicrobium s__uncultured_bacterium            10.713396
#  g__Christensenellaceae_R-7_group s__uncultured...     7.444778
#  g__Moryella s__human_gut                             10.247596
#  g__Bacteroides s__Bacteroides_finegoldii              6.767980
#
#                                                     log2FoldChange     lfcSE  \
# geneid
#  g__Escherichia-Shigella                                 15.285983  5.705350
#  g__Asteroleplasma s__uncultured_bacterium                0.929493  4.322670
#  g__Agathobacter                                         -2.909516  4.241998
#  g__Faecalibacterium                                    -11.778568  5.684878
#  g__Dialister                                           -11.718253  5.686845
# ...                                                            ...       ...
#  g__Family_XIII_AD3011_group s__metagenome                6.503808  6.529910
#  g__Elusimicrobium s__uncultured_bacterium                6.960748  6.527676
#  g__Christensenellaceae_R-7_group s__uncultured...        6.439782  6.530284
#  g__Moryella s__human_gut                                 6.896542  6.527949
#  g__Bacteroides s__Bacteroides_finegoldii                 6.302522  6.531142
#
#                                                         stat    pvalue  \
# geneid
#  g__Escherichia-Shigella                            2.679237  0.007379
#  g__Asteroleplasma s__uncultured_bacterium          0.215028  0.829746
#  g__Agathobacter                                   -0.685883  0.492787
#  g__Faecalibacterium                               -2.071912  0.038274
#  g__Dialister                                      -2.060589  0.039342
# ...                                                      ...       ...
#  g__Family_XIII_AD3011_group s__metagenome          0.996003  0.319249
#  g__Elusimicrobium s__uncultured_bacterium          1.066344  0.286268
#  g__Christensenellaceae_R-7_group s__uncultured...  0.986141  0.324064
#  g__Moryella s__human_gut                           1.056464  0.290756
#  g__Bacteroides s__Bacteroides_finegoldii           0.964995  0.334547
#
#                                                         padj
# geneid
#  g__Escherichia-Shigella                            0.306957
#  g__Asteroleplasma s__uncultured_bacterium          0.860265
#  g__Agathobacter                                    0.529289
#  g__Faecalibacterium                                0.306957
#  g__Dialister                                       0.306957
# ...                                                      ...
#  g__Family_XIII_AD3011_group s__metagenome          0.349367
#  g__Elusimicrobium s__uncultured_bacterium          0.321359
#  g__Christensenellaceae_R-7_group s__uncultured...  0.352419
#  g__Moryella s__human_gut                           0.324305
#  g__Bacteroides s__Bacteroides_finegoldii           0.361560
#
# [174 rows x 6 columns]

# %%
type(stat_res)
# Out:
# pydeseq2.ds.DeseqStats

# %%
pip install sanbomics
# Out:
# Collecting sanbomics
#   Downloading sanbomics-0.1.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 2.4 MB/s eta 0:00:002.4 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.0 in ./miniconda3/lib/python3.10/site-packages (from sanbomics) (2.0.3)
# Requirement already satisfied: numpy>=1.17.0 in ./miniconda3/lib/python3.10/site-packages (from sanbomics) (1.24.3)
# Requirement already satisfied: matplotlib>=3.4 in ./miniconda3/lib/python3.10/site-packages (from sanbomics) (3.7.1)
# Collecting seaborn (from sanbomics)
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 3.2 MB/s eta 0:00:003.8 MB/s eta 0:00:01
# Collecting adjustText>=0.7.3 (from sanbomics)
#   Downloading adjustText-0.8-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: scipy>=1.9.1 in ./miniconda3/lib/python3.10/site-packages (from sanbomics) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./miniconda3/lib/python3.10/site-packages (from matplotlib>=3.4->sanbomics) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in ./miniconda3/lib/python3.10/site-packages (from matplotlib>=3.4->sanbomics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./miniconda3/lib/python3.10/site-packages (from matplotlib>=3.4->sanbomics) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./miniconda3/lib/python3.10/site-packages (from matplotlib>=3.4->sanbomics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./miniconda3/lib/python3.10/site-packages (from matplotlib>=3.4->sanbomics) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in ./miniconda3/lib/python3.10/site-packages (from matplotlib>=3.4->sanbomics) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./miniconda3/lib/python3.10/site-packages (from matplotlib>=3.4->sanbomics) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./miniconda3/lib/python3.10/site-packages (from matplotlib>=3.4->sanbomics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./miniconda3/lib/python3.10/site-packages (from pandas>=1.0->sanbomics) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./miniconda3/lib/python3.10/site-packages (from pandas>=1.0->sanbomics) (2023.3)
# Requirement already satisfied: six>=1.5 in ./miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.4->sanbomics) (1.16.0)
# Installing collected packages: seaborn, adjustText, sanbomics
# Successfully installed adjustText-0.8 sanbomics-0.1.0 seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from sanbomics.tools import id_map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sanbomics.tools import id_map
#
# ModuleNotFoundError: No module named 'sanbomics'

# %%
mapper = id_map(species = 'human')

# %%
res['Symbol'] = res.index.map(mapper.mapper)

# %%
res

# %%
res = res[res.baseMean >= 10]
res

# %%
sigs = res[(res.padj < 0.05) & (abs(res.log2FoldChange) > 0.5)]
sigs

# %%
#PCA
import scanpy as sc

# %%
dds

# %%
sc.tl.pca(dds)

# %%
sc.pl.pca(dds, color = 'Condition', size = 200)

# %%
#GSEA

import gseapy as gp
from gseapy.plot import gseaplot

# %%
ranking = res[['Symbol', 'stat']].dropna().sort_values('stat', ascending = False)
ranking

# %%
ranking = ranking.drop_duplicates('Symbol')
ranking

# %%
manual_set = {'things':['STAU2', 'USP53', 'SERPINE1', 'TMEM178B', 'PSAP']}

# %%
#gp.get_library_name() #to look at available libraries

# %%
pre_res = gp.prerank(rnk = ranking,
                     gene_sets = ['GO_Biological_Process_2021', manual_set],
                     seed = 6, permutation_num = 100)

# %%
out = []

for term in list(pre_res.results):
    out.append([term,
               pre_res.results[term]['fdr'],
               pre_res.results[term]['es'],
               pre_res.results[term]['nes']])

out_df = pd.DataFrame(out, columns = ['Term','fdr', 'es', 'nes']).sort_values('fdr').reset_index(drop = True)
out_df

# %%
out_df.sort_values('nes').iloc[0].Term

# %%
gseaplot(pre_res.ranking,
         term = 'GO_Biological_Process_2021__mitotic spindle organization (GO:0007052)',
         **pre_res.results['GO_Biological_Process_2021__mitotic spindle organization (GO:0007052)'])

# %%
import numpy as np
import seaborn as sns

# %%
dds.layers['normed_counts']

# %%
dds.layers['log1p'] = np.log1p(dds.layers['normed_counts'])

# %%
dds.layers['log1p']

# %%
dds_sigs = dds[:, sigs.index]
dds_sigs

# %%
grapher = pd.DataFrame(dds_sigs.layers['log1p'].T,
                       index=dds_sigs.var_names, columns=dds_sigs.obs_names)

# %%
sns.clustermap(grapher, z_score=0, cmap = 'RdYlBu_r')

# %%
with open('senGPT.txt') as f:
    senGPT = [x.strip() for x in list(f)]

# %%
senGPT

# %%
sigs[sigs.Symbol.isin(senGPT)].index

# %%
dds_sub = dds[:, sigs[sigs.Symbol.isin(senGPT)].index]

# %%
dds_sub

# %%
grapher = pd.DataFrame(dds_sub.layers['log1p'].T,
                       index=dds_sub.var_names, columns=dds_sub.obs_names)

# %%
grapher.index = grapher.index.map(mapper.mapper)
grapher

# %%
ax = sns.clustermap(grapher, z_score=0, cmap = 'RdYlBu_r', figsize=(4,4))

# %%
#volcano
from sanbomics.plots import volcano

# %%
res

# %%
volcano(res, symbol='Symbol')

# %%
grapher.index

# %%
volcano(res, symbol='Symbol', to_label = grapher.index)
